# %%
import pandas as pd
df = pd.read_csv('/home/userroot/dev/iTransformer/data_prep/index_300/sh600036.csv')

# %%
#plot df with matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import seaborn as sns
sns.set()
for file in os.listdir('./index_300'):
    if file.endswith('.csv'):
        df = pd.read_csv(f'./index_300/{file}')
        df['date'] = pd.to_datetime(df['date'])
        df.set_index('date', inplace=True)
        df[['close']].plot( marker="o",figsize=(20,10))
        plt.title(file[:-4])
        plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import seaborn as sns
sns.set()
for file in os.listdir('./index_300'):
    if file.endswith('.csv'):
        df = pd.read_csv(f'./index_300/{file}')
        df['date'] = pd.to_datetime(df['date'])
        df.set_index('date', inplace=True)
        df[['close']][:10].plot( marker="o",figsize=(20,10))
        plt.title(file[:-4])
        plt.show()
        break

# %%
df
# Out:
#                          code  idx         0         1         2         3  \
# date
# 2023-10-30 08:15:00  sz000858    5  0.066665 -0.011196 -0.000925  0.068971
# 2023-10-30 08:40:00  sz000858    5  0.107544 -0.039354 -0.021378  0.128415
# 2023-10-30 10:00:00  sz000858    5  0.071857 -0.015774  0.047872  0.046034
# 2023-10-30 10:30:00  sz000858    5  0.134936 -0.039340  0.041390  0.114099
# 2023-10-30 10:40:00  sz000858    5  0.075049 -0.070006  0.039732  0.107123
# ...                       ...  ...       ...       ...       ...       ...
# 2024-04-02 12:53:00  sz000858    5  0.087731  0.030784  0.063211  0.052412
# 2024-04-02 17:34:00  sz000858    5  0.079742 -0.018814  0.036043  0.070966
# 2024-04-02 22:29:00  sz000858    5  0.192680  0.072921  0.046187  0.081779
# 2024-04-03 02:16:00  sz000858    5  0.015298  0.053159  0.105899 -0.008014
# 2024-04-03 13:01:00  sz000858    5 -0.002957  0.017523  0.049204  0.142140
#
# ...
